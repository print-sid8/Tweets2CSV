# %%
import json
import csv
import tweepy
import re
import datetime

# %%
"""
INPUTS:
    consumer_key, consumer_secret, access_token, access_token_secret: codes 
    telling twitter that we are authorized to access this data
    hashtag_phrase: the combination of hashtags to search for
OUTPUTS:
    none, simply save the tweet info to a spreadsheet
"""
def search_for_hashtags(consumer_key, consumer_secret, access_token, access_token_secret, hashtag_phrase):
    
    #create authentication for accessing Twitter
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    #initialize Tweepy API
    api = tweepy.API(auth)
    
    #get the name of the spreadsheet we will write to
    fname = '_'.join(re.findall(r"#(\w+)", hashtag_phrase))
    

    #open the spreadsheet we will write to
    with open('%s.csv' % (fname), 'w', encoding = 'utf8') as file:

        w = csv.writer(file)

        #write header row to spreadsheet
        w.writerow(['timestamp', 'tweet_text', 'username', 'all_hashtags', 'followers_count', 'User_Loc', 'Tweet Coord', 'Rt_count', 'Rt_YN', 'Phone'])

        #for each tweet matching our hashtags, write relevant info to the spreadsheet
        for tweet in tweepy.Cursor(api.search, q=hashtag_phrase+' -filter:retweets', \
                                   lang="en", tweet_mode='extended').items(9999):
            w.writerow([tweet.created_at, tweet.full_text.replace('\n',' ').encode('utf-8'), tweet.user.screen_name.encode('utf-8'), [e['text'] for e in tweet._json['entities']['hashtags']], tweet.user.followers_count, tweet.user.location, tweet.coordinates, tweet.retweet_count, tweet.retweeted, tweet.source, tweet.favorite_count, tweet.favorited])

# %%
consumer_key = input('Consumer Key ')
consumer_secret = input('Consumer Secret ')
access_token = input('Access Token ')
access_token_secret = input('Access Token Secret ')
    
hashtag_phrase = input('Hashtag Phrase ')

if __name__ == '__main__':
    search_for_hashtags(consumer_key, consumer_secret, access_token, access_token_secret, hashtag_phrase)
# Out:
# Consumer Key 38EWLI4EkHdFmc1m3PRyeml3C
# Consumer Secret cHNDuIU6Z0c0idnAcMUZudh0dAvPF2Oc5fDaLhmeCWUXlf96HZ
# Access Token 873966456630788097-llfhnBw6x2XxDNkMK305tXbabQ5sWK4
# Access Token Secret DdmGYIdbvlpBIxwM9sWjWv6M9gVIbEEra2H43ZEPhacI
# Hashtag Phrase #HowDareYou
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-3-97600f226d21> in <module>
#       7
#       8 if __name__ == '__main__':
# ----> 9     search_for_hashtags(consumer_key, consumer_secret, access_token, access_token_secret, hashtag_phrase)
#
# <ipython-input-2-afa2c306ca41> in search_for_hashtags(consumer_key, consumer_secret, access_token, access_token_secret, hashtag_phrase)
#      30         #for each tweet matching our hashtags, write relevant info to the spreadsheet
#      31         for tweet in tweepy.Cursor(api.search, q=hashtag_phrase+' -filter:retweets', \
# ---> 32                                    lang="en", tweet_mode='extended').items(9999):
#      33             w.writerow([tweet.created_at, tweet.full_text.replace('\n',' ').encode('utf-8'), tweet.user.screen_name.encode('utf-8'), [e['text'] for e in tweet._json['entities']['hashtags']], tweet.user.followers_count, tweet.user.location, tweet.coordinates, tweet.retweet_count, tweet.retweeted, tweet.source, tweet.favorite_count, tweet.favorited])
#
# D:\Anaconda\lib\site-packages\tweepy\cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# D:\Anaconda\lib\site-packages\tweepy\cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# D:\Anaconda\lib\site-packages\tweepy\cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# D:\Anaconda\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# D:\Anaconda\lib\site-packages\tweepy\binder.py in execute(self)
#     231                     raise RateLimitError(error_msg, resp)
#     232                 else:
# --> 233                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     234
#     235             # Parse the response payload
#
# TweepError: Twitter error response: status code = 401
